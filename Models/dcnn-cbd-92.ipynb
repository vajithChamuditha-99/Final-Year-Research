# %%
import random
import numpy as np
import math
import re
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import pickle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow_text as text
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from keras.models import load_model 
from keras.layers import Input, Concatenate, Dense
from keras.optimizers import Adam
from keras.models import Model
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
#Setting up a seed for reproducibility
seed = random.seed(42)

# %%
train_data = pd.read_csv('/kaggle/input/cb-final-dataset/cleaned_dataset.csv', header=0)
train_data.head()
# Out:
#    index  id                                            comment      lable  \
# 0      0   1  මෙතන ඉන්න එකම අවජාතකයා තෝ ! තෝ වගේ මෝඩ ගොබ්බයො...     Sexism
# 1      1   2  @USER තොට ජන්ද යක් වත් තියේද දන්නේ නෑ තෝ වගේ හ...  Offensive
# 2      2   3  මුස්ලිම් කරණයෙන් පවුල රැකගන්නට වෙහෙසෙන අපේ කෙල...     Racist
# 3      3   4  පිස්සා වගේ same to you කිය කිය යද්දි shame on ...    Neutral
# 4      4   5   "@NishadiAnuttara මොකක් ද මොකක් ද අැත්තට හෙට😁😁😁"    Neutral
#
#                                         Text_cleaned
# 0  මෙතන ඉන්න එකම අවජාතකයා තෝ  තෝ වගේ මෝඩ ගොබ්බයො ...
# 1  තොට ජන්ද යක් තියේද දන්නේ තෝ වගේ හාල්මැස්සන් රට...
# 2  මුස්ලිම් කරනයෙන් පවුල රැකගන්නට වෙහෙසෙන අපේ කෙල...
# 3  පිස්සා වගේ    කිය කිය යද්දි    කියලා කියවුනේ ම...
# 4                            මොකක් මොකක් අැත්තට හෙට

# %%
category_count = train_data['lable'].value_counts()

categories = category_count.index

category_count
# Out:
# Neutral      2377
# Offensive    1341
# Racist       1084
# Sexism       1062
# Name: lable, dtype: int64

# %% [markdown]
# # **Prepare dataset**
#
# Note that I have already cleaned the dataset.

# %%
# creates a new column 'encoded_text' in the train_data dataframe, 
# which contains the categorical codes for the 'label' column.

train_data['encoded_text'] = train_data['lable'].astype('category').cat.codes
train_data.head()
# Out:
#    index  id                                            comment      lable  \
# 0      0   1  මෙතන ඉන්න එකම අවජාතකයා තෝ ! තෝ වගේ මෝඩ ගොබ්බයො...     Sexism
# 1      1   2  @USER තොට ජන්ද යක් වත් තියේද දන්නේ නෑ තෝ වගේ හ...  Offensive
# 2      2   3  මුස්ලිම් කරණයෙන් පවුල රැකගන්නට වෙහෙසෙන අපේ කෙල...     Racist
# 3      3   4  පිස්සා වගේ same to you කිය කිය යද්දි shame on ...    Neutral
# 4      4   5   "@NishadiAnuttara මොකක් ද මොකක් ද අැත්තට හෙට😁😁😁"    Neutral
#
#                                         Text_cleaned  encoded_text
# 0  මෙතන ඉන්න එකම අවජාතකයා තෝ  තෝ වගේ මෝඩ ගොබ්බයො ...             3
# 1  තොට ජන්ද යක් තියේද දන්නේ තෝ වගේ හාල්මැස්සන් රට...             1
# 2  මුස්ලිම් කරනයෙන් පවුල රැකගන්නට වෙහෙසෙන අපේ කෙල...             2
# 3  පිස්සා වගේ    කිය කිය යද්දි    කියලා කියවුනේ ම...             0
# 4                            මොකක් මොකක් අැත්තට හෙට              0

# %%
train_data['encoded_text'].value_counts()
# Out:
# 0    2377
# 1    1341
# 2    1084
# 3    1062
# Name: encoded_text, dtype: int64

# %%
# drops the first 4 columns (index, id, comment, and lable) from the train_data DataFrame 
# and assigns the resulting DataFrame to train_data.

train_data = train_data.drop(train_data.columns[[0, 1, 2, 3]], axis=1)
train_data.head()
# Out:
#                                         Text_cleaned  encoded_text
# 0  මෙතන ඉන්න එකම අවජාතකයා තෝ  තෝ වගේ මෝඩ ගොබ්බයො ...             3
# 1  තොට ජන්ද යක් තියේද දන්නේ තෝ වගේ හාල්මැස්සන් රට...             1
# 2  මුස්ලිම් කරනයෙන් පවුල රැකගන්නට වෙහෙසෙන අපේ කෙල...             2
# 3  පිස්සා වගේ    කිය කිය යද්දි    කියලා කියවුනේ ම...             0
# 4                            මොකක් මොකක් අැත්තට හෙට              0

# %%
# renames the columns of the pandas DataFrame train_data to "text" and "label".

train_data.columns = ['text', 'label']
train_data.head(3)
# Out:
#                                                 text  label
# 0  මෙතන ඉන්න එකම අවජාතකයා තෝ  තෝ වගේ මෝඩ ගොබ්බයො ...      3
# 1  තොට ජන්ද යක් තියේද දන්නේ තෝ වගේ හාල්මැස්සන් රට...      1
# 2  මුස්ලිම් කරනයෙන් පවුල රැකගන්නට වෙහෙසෙන අපේ කෙල...      2

# %%
# removes any leading whitespaces using the lstrip() method, and returns the cleaned phrase.

def clean_data(phrase):
    phrase = phrase.lstrip()
    return phrase

# %%
train_data['text'] = train_data['text'].astype(str)
train_data['text'] = train_data['text'].map(lambda x: clean_data(x))
train_data.head()
# Out:
#                                                 text  label
# 0  මෙතන ඉන්න එකම අවජාතකයා තෝ  තෝ වගේ මෝඩ ගොබ්බයො ...      3
# 1  තොට ජන්ද යක් තියේද දන්නේ තෝ වගේ හාල්මැස්සන් රට...      1
# 2  මුස්ලිම් කරනයෙන් පවුල රැකගන්නට වෙහෙසෙන අපේ කෙල...      2
# 3  පිස්සා වගේ    කිය කිය යද්දි    කියලා කියවුනේ ම...      0
# 4                            මොකක් මොකක් අැත්තට හෙට       0

# %%
train_data.to_csv("train_data_cleaned.csv", index=False)

# %%
tokenizer = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    train_data.text, target_vocab_size=100000)

# %%
train_inputs = [tokenizer.encode(sentence) for sentence in train_data.text]

# %%
# Get the vocabulary size from the tokenizer
vocab_size = tokenizer.vocab_size

# Create a dictionary that maps each subword to its index in the tokenizer
word_index = {subword: index+1 for index, subword in enumerate(tokenizer.subwords)}

# %%
embedding_dim = 300

# %%
# Loading pretrained FastText word embeddings in Sinhala
import fasttext
import fasttext.util
ft = fasttext.load_model('/kaggle/input/fast-text/cc.si.300.bin')
ft.get_dimension()

# Mapping FastText word vectors with word in the dataset 
embeddings_matrix = np.zeros((vocab_size+1, embedding_dim));
for word, i in word_index.items():
    embedding_vector = ft.get_word_vector(word)
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector;
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
# sets the maximum length of the sentences in a dataset, and pads the sentences with zeros 
# to the same length to ensure consistency when using them to train or test a model.

MAX_LEN = max([len(sentence) for sentence in train_inputs])
# Pad the training data
train_inputs = tf.keras.preprocessing.sequence.pad_sequences(
    train_inputs, value=0, padding="post", maxlen=MAX_LEN)

# %%
# saves the train_inputs and test_inputs arrays as binary files using the pickle module, 
# which can be loaded later for use in training or testing machine learning models.

with open('train_inputs', 'wb') as fh:
   pickle.dump(train_inputs, fh)

# %%
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(train_inputs, train_data.label, test_size=0.2, random_state=seed)

# %% [markdown]
# # **Building the model**

# %%
# Define the hyperparameters
VOCAB_SIZE = 5297
EMB_DIM = 300
NB_CLASSES = 4
DROPOUT_RATE = 0.1
EPOCHS = 10
BATCH_SIZE = 32

# %%
def DCNNModel(embeddings_matrix,
              vocab_size,
              emb_dim=300,
              nb_filters=100,
              FFN_units=256,
              nb_classes=4,
              dropout_rate=0.1,
              training=False,
              name="DCNN"):
    
    inputs = layers.Input(shape=(None,), name="input")
    x = layers.Embedding(vocab_size, emb_dim, weights=[embeddings_matrix],
                         trainable=False, name="embedding")(inputs)
    
    # Convolutional layers
    conv1 = layers.Conv1D(filters=nb_filters,
                          kernel_size=2,
                          padding="valid",
                          activation="relu",
                          name="conv1")(x)
    conv1 = layers.GlobalMaxPool1D(name="pool1")(conv1)
    
    conv2 = layers.Conv1D(filters=nb_filters,
                          kernel_size=3,
                          padding="valid",
                          activation="relu",
                          name="conv2")(x)
    conv2 = layers.GlobalMaxPool1D(name="pool2")(conv2)
    
    x = layers.concatenate([conv1, conv2], axis=-1, name="concat")
    
    # Feedforward neural network layers
    x = layers.Dense(units=FFN_units, activation="relu", name="dense")(x)
    # Dropout is only applied during training to prevent overfitting
    x = layers.Dropout(rate=dropout_rate, name="dropout")(x, training=training)
    
    # Output layer
    outputs = layers.Dense(units=nb_classes, activation="softmax", name="output")(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs, name=name)
    
    return model

# %%
dcnn_model = DCNNModel(embeddings_matrix,vocab_size=VOCAB_SIZE,
            emb_dim=EMB_DIM,
            nb_filters=100,
            FFN_units=256,
            nb_classes=NB_CLASSES,
            dropout_rate=DROPOUT_RATE,
            training=False,
            name="dcnn")

# %%
 dcnn_model.compile(loss="sparse_categorical_crossentropy",  #Standard loss when doing a multiclass classification
                 optimizer="adam",
                 metrics=["accuracy"])

# %%
filepath="dcnn_model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
dcnn_history = dcnn_model.fit(X_train, 
                 y_train,
                 batch_size=BATCH_SIZE,
                 epochs=EPOCHS, validation_data=(X_test, y_test), callbacks = callbacks_list)
# Out:
# Epoch 1/10
# 147/147 [==============================] - ETA: 0s - loss: 1.1235 - accuracy: 0.5137
# Epoch 1: val_accuracy improved from -inf to 0.66222, saving model to dcnn_model.h5
# 147/147 [==============================] - 47s 311ms/step - loss: 1.1235 - accuracy: 0.5137 - val_loss: 0.8575 - val_accuracy: 0.6622
# Epoch 2/10
# 147/147 [==============================] - ETA: 0s - loss: 0.8028 - accuracy: 0.6924
# Epoch 2: val_accuracy improved from 0.66222 to 0.72938, saving model to dcnn_model.h5
# 147/147 [==============================] - 46s 311ms/step - loss: 0.8028 - accuracy: 0.6924 - val_loss: 0.7110 - val_accuracy: 0.7294
# Epoch 3/10
# 147/147 [==============================] - ETA: 0s - loss: 0.6553 - accuracy: 0.7512
# Epoch 3: val_accuracy improved from 0.72938 to 0.76000, saving model to dcnn_model.h5
# 147/147 [==============================] - 45s 308ms/step - loss: 0.6553 - accuracy: 0.7512 - val_loss: 0.6241 - val_accuracy: 0.7600
# Epoch 4/10
# 147/147 [==============================] - ETA: 0s - loss: 0.5628 - accuracy: 0.7917
# Epoch 4: val_accuracy improved from 0.76000 to 0.80938, saving model to dcnn_model.h5
# 147/147 [==============================] - 46s 310ms/step - loss: 0.5628 - accuracy: 0.7917 - val_loss: 0.5081 - val_accuracy: 0.8094
# Epoch 5/10
# 147/147 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.8307
# Epoch 5: val_accuracy improved from 0.80938 to 0.83259, saving model to dcnn_model.h5
# 147/147 [==============================] - 46s 312ms/step - loss: 0.4640 - accuracy: 0.8307 - val_loss: 0.4528 - val_accuracy: 0.8326
# Epoch 6/10
# 147/147 [==============================] - ETA: 0s - loss: 0.4018 - accuracy: 0.8493
# Epoch 6: val_accuracy did not improve from 0.83259
# 147/147 [==============================] - 46s 315ms/step - loss: 0.4018 - accuracy: 0.8493 - val_loss: 0.4705 - val_accuracy: 0.8321
# Epoch 7/10
# 147/147 [==============================] - ETA: 0s - loss: 0.3408 - accuracy: 0.8680
# Epoch 7: val_accuracy improved from 0.83259 to 0.85827, saving model to dcnn_model.h5
# 147/147 [==============================] - 47s 319ms/step - loss: 0.3408 - accuracy: 0.8680 - val_loss: 0.3996 - val_accuracy: 0.8583
# Epoch 8/10
# 147/147 [==============================] - ETA: 0s - loss: 0.2826 - accuracy: 0.8964
# Epoch 8: val_accuracy improved from 0.85827 to 0.89136, saving model to dcnn_model.h5
# 147/147 [==============================] - 46s 314ms/step - loss: 0.2826 - accuracy: 0.8964 - val_loss: 0.3273 - val_accuracy: 0.8914
# Epoch 9/10
# 147/147 [==============================] - ETA: 0s - loss: 0.2076 - accuracy: 0.9290
# Epoch 9: val_accuracy improved from 0.89136 to 0.92395, saving model to dcnn_model.h5
# 147/147 [==============================] - 46s 312ms/step - loss: 0.2076 - accuracy: 0.9290 - val_loss: 0.2752 - val_accuracy: 0.9240
# Epoch 10/10
# 147/147 [==============================] - ETA: 0s - loss: 0.1520 - accuracy: 0.9484
# Epoch 10: val_accuracy did not improve from 0.92395
# 147/147 [==============================] - 46s 311ms/step - loss: 0.1520 - accuracy: 0.9484 - val_loss: 0.2730 - val_accuracy: 0.9205

# %%
from tensorflow.keras.utils import plot_model

plot_model(dcnn_model, to_file='model.png',show_shapes=True, show_layer_names=True, expand_nested=True)

# %% [markdown]
# # **Evaluation**

# %%
dcnn = tf.keras.models.load_model('dcnn_model.h5')

# %%
train_loss, train_acc = dcnn.evaluate(X_train, y_train, batch_size=BATCH_SIZE)
val_loss, val_acc = dcnn.evaluate(X_test, y_test, batch_size=BATCH_SIZE)

print('Training loss: {}, Training accuracy: {}'.format(train_loss, train_acc))
print('Validation loss: {}, Validation accuracy: {}'.format(val_loss, val_acc))
# Out:
# 147/147 [==============================] - 16s 109ms/step - loss: 0.1147 - accuracy: 0.9736
# 64/64 [==============================] - 7s 105ms/step - loss: 0.2752 - accuracy: 0.9240
# Training loss: 0.11471042037010193, Training accuracy: 0.9735664129257202
# Validation loss: 0.27520397305488586, Validation accuracy: 0.9239506125450134

# %%
output = dcnn(np.array([tokenizer.encode("දෙමලු.තම්බි රටෙන් එලවන්ට එකග උන් කොො")]), training=False).numpy()
highest_index = np.argmax(output)
print(output)

# Calculate the sum of the output array
sum_output = sum(output[0])

for i in range(len(output[0])):
    output[0][i] = output[0][i] / sum_output * 100
    print(f"Class {i}: {output[0][i]:.2f}%")
print("")
print("Heighest match: Class " , highest_index)
# Out:
# [[3.3615909e-03 2.9851039e-06 9.9662799e-01 7.4017726e-06]]
# Class 0: 0.34%
# Class 1: 0.00%
# Class 2: 99.66%
# Class 3: 0.00%
#
# Heighest match: Class  2

# %%
output = dcnn(np.array([tokenizer.encode("මෝඩ ගැනි")]), training=False).numpy()
highest_index = np.argmax(output)
print(output)

# Calculate the sum of the output array
sum_output = sum(output[0])

for i in range(len(output[0])):
    output[0][i] = output[0][i] / sum_output * 100
    print(f"Class {i}: {output[0][i]:.2f}%")
print("")
print("Heighest match: Class " , highest_index)
# Out:
# [[1.1489381e-02 9.8001498e-01 9.3818054e-04 7.5574168e-03]]
# Class 0: 1.15%
# Class 1: 98.00%
# Class 2: 0.09%
# Class 3: 0.76%
#
# Heighest match: Class  1

# %%
# Convert y_train and y_test to one-hot encoded format
y_train_one_hot = tf.keras.utils.to_categorical(y_train, num_classes=4)
y_test_one_hot = tf.keras.utils.to_categorical(y_test, num_classes=4)

# Compile the model
dcnn.compile(loss='mse', optimizer='adam', metrics=['mse', 'mae'])

# Evaluate the model on the test data
mse, mse_value, mae = dcnn.evaluate(X_test, y_test_one_hot, verbose=0)

# Print the results
print('MSE:', mse_value)
print('MAE:', mae)
# Out:
# MSE: 0.031520869582891464
# MAE: 0.06751438975334167

# %%
def plot_history(model, history):
    """
    Plots the loss and accuracy graphs for the given model and its training history.
    """
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(f'{model.name} accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(f'{model.name} loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='upper left')
    plt.show()

# %%
plot_history(dcnn, dcnn_history)

# %%
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
import numpy as np

# Generate predicted probabilities for each class
y_prob = dcnn.predict(X_test)

# Calculate the ROC AUC score for each class
auc_scores = []
for i in range(NB_CLASSES):
    y_true = (y_test == i).astype(int)
    auc_scores.append(roc_auc_score(y_true, y_prob[:, i]))

# Plot the ROC curve for each class
plt.figure(figsize=(8, 6))
for i in range(NB_CLASSES):
    y_true = (y_test == i).astype(int)
    fpr, tpr, _ = roc_curve(y_true, y_prob[:, i])
    plt.plot(fpr, tpr, label=f'Class {i}, AUC={auc_scores[i]:.3f}')
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()
# Out:
# 37/37 [==============================] - 4s 114ms/step

# %%
y_pred = dcnn.predict(X_test)
y_pred = np.argmax(y_pred, axis=-1)

print(classification_report(y_test, y_pred))
# Out:
# 37/37 [==============================] - 4s 106ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95       458
#            1       0.88      0.86      0.87       266
#            2       0.98      0.94      0.96       221
#            3       0.90      0.85      0.87       228
#
#     accuracy                           0.92      1173
#    macro avg       0.92      0.91      0.92      1173
# weighted avg       0.92      0.92      0.92      1173

# %%
pred_labels = np.argmax(dcnn.predict(X_test), axis=-1)
conf_mat = confusion_matrix(y_test, pred_labels)
print(conf_mat)
# Out:
# 37/37 [==============================] - 4s 103ms/step
# [[449   5   2   2]
#  [ 17 230   1  18]
#  [  8   3 208   2]
#  [ 10  23   1 194]]
